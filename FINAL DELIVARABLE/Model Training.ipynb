# %% [markdown]
# # Real-Time Communication System Powered By AI For Specially Abled

# %% [markdown]
# Image Preprocessing

# %% [markdown]
# Import ImageDataGenerator Library And Configure It

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_datagen=ImageDataGenerator(rescale=1./255,horizontal_flip=True,vertical_flip=True,zoom_range=0.2)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Apply ImageDataGenerator Functionality To Train And Test Set

# %%
x_train=train_datagen.flow_from_directory(r"/content/drive/MyDrive/IBM-Project-321-1658278283-main/Data Collection/Train_Set",target_size=(64,64),
                                          class_mode="categorical",batch_size=30)
# Out:
# Found 14928 images belonging to 9 classes.

# %%
x_test=test_datagen.flow_from_directory(r"/content/drive/MyDrive/IBM-Project-321-1658278283-main/Data Collection/Test_set",target_size=(64,64),
                                                            class_mode="categorical",batch_size=30)
# Out:
# Found 2250 images belonging to 9 classes.

# %% [markdown]
# Model  Building
#
# Import The Required Model Building Libraries

# %%
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten

# %% [markdown]
# Initialize The Model

# %%
model=Sequential()
print("Model Initialized Successfully")
# Out:
# Model Initialized Successfully

# %% [markdown]
# Add The Convolution Layer

# %%
model.add(Convolution2D(32,(3,3),activation="relu",input_shape=(64,64,3)))
#No of feature detectors, size of feature detector, image size, activation function

# %% [markdown]
# Add The Pooling Layer

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# Add The Flatten Layer

# %%
model.add(Flatten())

# %% [markdown]
# Adding The Dense Layers

# %%
model.add(Dense(500,activation='relu'))

# %%
model.add(Dense(300,activation='relu'))

# %%
model.add(Dense(9,activation="softmax"))

# %% [markdown]
# Compile The Model

# %%
model.compile(loss="categorical_crossentropy",metrics=["accuracy"],optimizer='adam')

# %%
len(x_train)
# Out:
# 498

# %%
len(x_test)
# Out:
# 75

# %%
x_train.class_indices
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8}

# %% [markdown]
# Fit And Save The Model

# %%
model.fit(x_train,epochs=8,validation_data=x_test,steps_per_epoch=len(x_train),validation_steps=len(x_test))
# Out:
# Epoch 1/8
# 498/498 [==============================] - 153s 306ms/step - loss: 0.3205 - accuracy: 0.8952 - val_loss: 0.1615 - val_accuracy: 0.9564
# Epoch 2/8
# 498/498 [==============================] - 144s 288ms/step - loss: 0.0806 - accuracy: 0.9739 - val_loss: 0.2619 - val_accuracy: 0.9640
# Epoch 3/8
# 498/498 [==============================] - 144s 288ms/step - loss: 0.0585 - accuracy: 0.9806 - val_loss: 0.2421 - val_accuracy: 0.9667
# Epoch 4/8
# 498/498 [==============================] - 143s 286ms/step - loss: 0.0393 - accuracy: 0.9863 - val_loss: 0.2037 - val_accuracy: 0.9742
# Epoch 5/8
# 498/498 [==============================] - 143s 287ms/step - loss: 0.0410 - accuracy: 0.9849 - val_loss: 0.2781 - val_accuracy: 0.9733
# Epoch 6/8
# 498/498 [==============================] - 145s 290ms/step - loss: 0.0371 - accuracy: 0.9863 - val_loss: 0.1938 - val_accuracy: 0.9724
# Epoch 7/8
# 498/498 [==============================] - 142s 286ms/step - loss: 0.0352 - accuracy: 0.9867 - val_loss: 0.2283 - val_accuracy: 0.9729
# Epoch 8/8
# 498/498 [==============================] - 144s 289ms/step - loss: 0.0268 - accuracy: 0.9897 - val_loss: 0.3766 - val_accuracy: 0.9809

# %%
model.save("C:/Users/rajes/Downloads/signlanguage-new.h5")
